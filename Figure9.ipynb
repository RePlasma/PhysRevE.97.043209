# %% [markdown]
# ### Figure 9: evolution of momenta in time for different $\chi$

# %%
import numpy as np
from numpy import log, log10, sin, cos, exp, sqrt, pi
import pandas as pd
import glob as glob

# plotting
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib import cm

import json

# %%
fig, axs = plt.subplots(4, 3, figsize=(6, 7), layout='constrained')
mrksz = 2

################################################################
### fig 9 11
f = open('dataWPD/fig9_11/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[0,0].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)

### fig 9 12
f = open('dataWPD/fig9_12/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[0,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[0,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)

### fig 9 13
f = open('dataWPD/fig9_13/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[0,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[0,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[0,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='b', label='WPD', markersize=mrksz)

################################################################
### fig 9 21
f = open('dataWPD/fig9_21/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,0].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)

### fig 9 22
f = open('dataWPD/fig9_22/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='b', label='WPD', markersize=mrksz)

### fig 9 23
f = open('dataWPD/fig9_23/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[1,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='b', label='WPD', markersize=mrksz)

################################################################
### fig 9 31
f = open('dataWPD/fig9_31/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,0].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,0].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)

### fig 9 32
f = open('dataWPD/fig9_32/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='b', label='WPD', markersize=mrksz)

### fig 9 33
f = open('dataWPD/fig9_33/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[2,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='b', label='WPD', markersize=mrksz)

################################################################
### fig 9 41
f = open('dataWPD/fig9_41/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[3,0].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='k', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[3,0].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)

### fig 9 42
f = open('dataWPD/fig9_42/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[3,1].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)

### fig 9 43
f = open('dataWPD/fig9_43/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[3,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='r', label='WPD', markersize=mrksz)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
indxs = np.argsort(datatmp2[:,0])
axs[3,2].plot(datatmp2[:,0][indxs],datatmp2[:,1][indxs],'.', color='b', label='WPD', markersize=mrksz)

for i in range(3): axs[3,i].set_xlabel(r'$\omega_c~t$')
for i in range(4): axs[i,0].set_ylabel(r'$10^{-2}~\Delta \langle \gamma \rangle / \gamma_0$')
for i in range(2): axs[i,1].set_ylabel(r'$10^{-3}~ \sigma_\gamma^2/\gamma_0^2$')
for i in range(2): axs[i+2,1].set_ylabel(r'$10^{-2}~ \sigma_\gamma^2/\gamma_0^2$')
for i in range(4): axs[i,2].set_ylabel(r'$10^{'+str(np.array([-6,-5,-3,-2])[i])+'}~ \mu_3/\gamma_0^3$')
for i in range(3): axs[0,i].set_xlim([0,20]); axs[1,i].set_xlim([0,20]); axs[0,i].set_xticks(np.arange(0,21,5)); axs[1,i].set_xticks(np.arange(0,21,5))
for i in range(3): axs[2,i].set_xlim([0,5]); axs[2,i].set_xticks(np.arange(0,6,1));
for i in range(3): axs[3,i].set_xlim([0,3]); axs[3,i].set_xticks(np.arange(0,4,1));
for i in range(4): axs[i,0].set_ylim([-7,1]); axs[i,0].set_yticks(np.arange(-7,2,2));
for i in axs:
    for ax in i:
        ax.set_box_aspect(1)
plt.tight_layout()
plt.show()
